# %% [raw]
# Jika kita memiliki beberapa data yang menunjukkan hubungan antara jumlah jam belajar (X) dan nilai ujian (Y). Kita ingin menggunakan regresi linear untuk memahami bagaimana jumlah jam belajar memengaruhi nilai ujian.
#
# Kita punya data seperti ini:
# Jumlah Jam Belajar (X) Nilai Ujian (Y)
# X = 1, 2, 3, 4, 5
# Y = 60, 70, 80, 85, 90
#
# Tujuan kita adalah menemukan garis lurus terbaik yang dapat mewakili hubungan antara jumlah jam belajar dan nilai ujian. Garis ini dapat dinyatakan dalam persamaan:
# 𝑌 = 𝛽0 + 𝛽1 ⋅ 𝑋, Di sini, 𝛽0 adalah intercept (titik potong dengan sumbu Y) dan 𝛽1 adalah koefisien kemiringan (slope) dari garis.
# Metode OLS akan mencari nilai 𝛽0 dan 𝛽1 yang meminimalkan jumlah kesalahan kuadrat antara nilai yang diprediksi oleh garis tersebut dan nilai yang diamati dalam data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Data
X = np.array([[1], [2], [3], [4], [5]])
Y = np.array([60, 70, 80, 85, 90])

# %%
# Plot data
plt.scatter(X, Y, color='blue')
plt.xlabel('Jumlah Jam Belajar')
plt.ylabel('Nilai Ujian')
plt.title('Hubungan Jumlah Jam Belajar dan Nilai Ujian')
plt.grid(True)
plt.show()

# %%
# Regresi Linear dengan OLS
reg = LinearRegression()
reg.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Plot garis regresi
plt.scatter(X, Y, color='blue')
plt.plot(X, reg.predict(X), color='red', linewidth=3)
plt.xlabel('Jumlah Jam Belajar')
plt.ylabel('Nilai Ujian')
plt.title('Regresi Linear dengan OLS')
plt.grid(True)
plt.show()

# %%
# Menampilkan koefisien
print("Intercept (beta_0):", reg.intercept_)
print("Koefisien Kemiringan (beta_1):", reg.coef_[0])
# Out:
# Intercept (beta_0): 54.5
# Koefisien Kemiringan (beta_1): 7.500000000000001
